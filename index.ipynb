# %% [markdown]
# # Introduction to Data Science for Business

# %%
# Step 1: Importing the necessary libraries.
import pandas as pd # module for data analysis
import numpy as np  # module for efficient computations
import matplotlib.pyplot as plt # module for plotting visualizations
import seaborn as sns        # module for visualisation
